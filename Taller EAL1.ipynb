# %%
#Implementar los dos pasos de eliminacion de Gauss simple: eliminacion hacia
#adelante de incognitas, sustitucion hacia atras

def Matriz(n,m):
    matriz = []
    for i in range(n):
        matriz.append([])
        for j in range(m):
            numero=input("ingrese %d%d:" % (i,j))
            matriz[i].append(numero)        
    return matriz
    


factor=0.0

def HaciaAdelante():    
    n=input("Ingrese n: ")    
    a=crearMatriz(n,n)
    b=[]
    x= [0.0]*n
    for i in range(0,n):
        b.append(input("Ingrese b[%d]" % i))
    for k in range(0,n-1):
        for i in range(k+1,n):
            factor=(a[i][k])/(a[k][k])
            for j in range(k,n):
                a[i][j]=a[i][j]-factor*a[k][j]
            b[i]=b[i]-factor*b[k]
            
    print a
    x[n-1]=b[n-1]/a[n-1][n-1]
    for i in range(n-1,-1,-1):
        sum=b[i]
        for j in range(i+1,n):
            sum=sum - (a[i][j])*x[j]
        x[i]=sum/a[i][i]
    print x
            
HaciaAdelante()
# Out:
# Ingrese n: 2

# %%
#Desarrollar los ejercicios 9.1 al 9.8 Pags. 279-280

# 9.1 A
$\begin{pmatrix}
0 & 2 & 5 \\
1 & 0 & 1 \\
8 & 3 & 0 
\end{pmatrix} $
=
$\begin{pmatrix}
50 \\
10  \\
20  
\end{pmatrix} $

# 9.1 B
$\begin{pmatrix}
0 & 1 & 8 \\
2 & 0 & 3 \\
5 & 1 & 0 
\end{pmatrix} $

#9.2 A
[A]=3x2

[B]=3x3

[C]=3x1

[D]=2x4

[E]=3x3

[F]=2x3

[G]=1x2

#9.2 B
Cuadrada= [B]

Columna = [C]

Renglon = [G]
 

#9.2 C
a[12]= 7

b[23]=7

d[32]=NO existe

e[22]=2

f[12]=0

g[12]=6

#9.2 D

1) [E] + [B] = $\begin{pmatrix}
5 & 8 & 15 \\
8 & 4 & 10 \\
5 & 0 & 10 
\end{pmatrix} $

2) [A] + [F] = Matrices de dimenciones diferentes 

3) [B] – [E] =  $\begin{pmatrix}
3 & -2 & -1 \\
-6 & 0 & 4 \\
-3 & 0 & -2 
\end{pmatrix} $

4) 7 × [B]= $\begin{pmatrix}
5 & 8 & 15 \\
8 & 4 & 10 \\
5 & 0 & 10 
\end{pmatrix} $

5) [E] × [B] = $\begin{pmatrix}
17 & 13 & 74 \\
33 & 25 & 75 \\
22 & 12 & 52 
\end{pmatrix} $

6) {C}T = $\begin{pmatrix}
3& 6 & 1 \\
\end{pmatrix} $

7) [B] × [A] =  $\begin{pmatrix}
54 & 76  \\
41 & 53 \\
24 & 31 
\end{pmatrix} $

8) [D]T=  $\begin{pmatrix}
9 & 2  \\
4 & -1  \\
3 & 7  \\
-6 & 5
\end{pmatrix} $

9) [A] × {C}= No se puede realizar la operacion


10)[I] × [B]= $\begin{pmatrix} 
4 & 3 & 7 \\
1 & 2 & 7 \\
1 & 0 & 4
\end{pmatrix}$

11) [E]T [E]= $\begin{pmatrix}
1 & 7 & 4 \\
5 & 2 & 0 \\
8 & 3 & 6
\end{pmatrix}$


12) {C}T {C}=  $\begin{pmatrix}
3 \\
6 \\
1
\end{pmatrix}$

# %% [markdown]
# #9.3 A
#
# 1) [A] x [B]= $
# \begin{pmatrix}
# 4 & 15\\
# 8 & 29 \\
# 9 & 29
# \end{pmatrix}
# $
#
# 2) [A] x [C]= $
# \begin{pmatrix}
# -16 & 4\\
# -24 & 4 \\
# 2 & -10
# \end{pmatrix}
# $
#
# 3) [B] x [C]= $
# \begin{pmatrix}
# -7 & 1\\
# -5 & 1
# \end{pmatrix}
# $
#
# 4) [C] x [D]= $
# \begin{pmatrix}
# 1 & 2\\
# -2.5 & -7
# \end{pmatrix}
# $
#
# # 9.3 B
#
# Dos matrices son multiplicables si el número de columnas de A coincide con el numero de filas de B; ademas las el numero
# de filas de la primera matriz y las columnas de la segunda matriz definen las dimenciones de la matriz resultado.
#
# #9.3 C
#
# Normalmente sabemos que una de las propiedades de la multiplicacion es la conmutativa, pero en el caso de la multiplicacion
# de matices esta regla no aplica ya que [A]x[B]es diferente a [B]x[A], con [A] y [B] matrices no cuadradas.
# ejm. [A]=3x2 (dimencion).
#      [B]=3x3 (dimencion).
#      la multiplicacion de [B]x[A]=3x3 (dimencion); puede ejecutarse la operacion.
#      la multiplicacion de [A]x[B]  puede ejecutarse la operacion.

# %%
#9.4

import math 
import numpy as np
import pylab as pl
from pylab import *

class MyClass(object):
    
    def  funcion1(x):
        Fx= 3 -(x/2)
        return Fx
    funcion1 = staticmethod(funcion1)
    
    def  funcion2(x):
        Fx= (17/3) - (x/6)
        return Fx
    funcion2 = staticmethod(funcion2)
    
    def graficar():
        
        i=-10.0
        fx1=[]
        fx2=[]
        iteracion=[]
        
        while i<=5.0:
            
            fx1.append(MyClass.funcion1(i))
            fx2.append(MyClass.funcion2(i))
            
            iteracion.append(i)
            i=i+0.5

        plt.subplot(2,1,1)

        plt.plot(iteracion,fx1,label = "Funcion1")
        plt.plot(iteracion,fx2,label = "funcion2")
        plt.grid(True)
        plt.show()
    
    print ("reemplazando en las ecucion x1=4 y x2=5 tenemos que se cumple la igualdad")
    print (" 4(4) – 8(5) = –24 2  &  (4) + 6(5) = 34 ")

        
    graficar = staticmethod(graficar)
    
    
j=MyClass.graficar()
# Out:
# reemplazando en las ecucion x1=4 y x2=5 tenemos que se cumple la igualdad
#  4(4) – 8(5) = –24 2  &  (4) + 6(5) = 34

# %%
#9.5

import math 
import numpy as np
import pylab as pl
from pylab import *

class MyClass(object):
    
    def  funcion1(x):
        Fx= (120 + 1.1*x) / 10
        return Fx
    funcion1 = staticmethod(funcion1)
    
    def  funcion2(x):
        Fx= (174 + 2*x)/ 17.4
        return Fx
    funcion2 = staticmethod(funcion2)
    
    def graficar():
        
        i=-30.0
        fx1=[]
        fx2=[]
        iteracion=[]
        
        while i<=30.0:
            
            fx1.append(MyClass.funcion1(i))
            fx2.append(MyClass.funcion2(i))
            
            iteracion.append(i)
            i=i+0.5

        plt.subplot(2,1,1)

        plt.plot(iteracion,fx1,label = "Funcion1")
        plt.plot(iteracion,fx2,label = "funcion2")
        plt.grid(True)
        plt.show()
        
    graficar = staticmethod(graficar)
    
    
j=MyClass.graficar()

# %% [markdown]
#  # 9.5 A  &  9.5 B
#     Observamos que el sistema de ecuaciones al ser solucionado gráficamente no presenta una posible solución ya
#     que no se puede determinar una solución precisa.
#
# #9.5 C
#
# det|A| = $
# \begin{pmatrix}
# -1.1 & 10\\
# -2 & 17.4
# \end{pmatrix}
# $ = (-1.1)	 * 	(17.4)	 - 	(-2)	 * 	(10)
# = 0.86
#
# #9.5 D
#
# x2 = $
# \begin{equation}
# \frac{(-1.1*174) + (2*120)}{(-1.1*17.4) + (10*2)}
# \end{equation}
# $ = 56.5
#
# x1 = $
# \begin{equation}
# \frac{(17.4*120) - (10*174)}{(-1.1*17.4) + (10*2)}
# \end{equation}
# $ = 404.65

# %%
# 9.6 A

det|A| = $
\begin{pmatrix}
0 & 2 & 5\\
2 & 1 & 1\\
3 & 1 & 0
\end{pmatrix}
$ = 1

# 9.6 B

det|A| = $
\begin{pmatrix}
0 & 2 & 5\\
2 & 1 & 1\\
3 & 1 & 0
\end{pmatrix}
$ = 1

A1 = $
\begin{pmatrix}
9 & 2 & 5\\
9 & 1 & 1\\
10 & 1 & 0
\end{pmatrix}
$ = 6

A2 = $
\begin{pmatrix}
0 & 9 & 5\\
2 & 9 & 1\\
3 & 10 & 0
\end{pmatrix}
$ = -8

A3 = $
\begin{pmatrix}
0 & 2 & 9\\
2 & 1 & 9\\
3 & 1 & 10
\end{pmatrix}
$ = 5

x1 =$
\begin{equation}
\frac{A1}{det|A|}
\end{equation}
$ = 6

x2 = $
\begin{equation}
\frac{A2}{det|A|}
\end{equation}
$ = -8

x3 = $
\begin{equation}
\frac{A3}{det|A|}
\end{equation}
$ = 5

#9.6 C

2(-8) + 5(5) = 9

2(6) + (-8) + 5 = 9

3(6) + (-8) = 10

# %%
#9.7 A

import math 
import numpy as np
import pylab as pl
from pylab import *

class MyClass(object):
    
    def  funcion1(x):
        Fx= (9.5 + (0.5*x))
        return Fx
    funcion1 = staticmethod(funcion1)
    
    def  funcion2(x):
        Fx= (18.8 + (1.02*x))/2
        return Fx
    funcion2 = staticmethod(funcion2)
    
    def graficar():
        
        i=-10.0
        fx1=[]
        fx2=[]
        iteracion=[]
        
        while i<=10.0:
            
            fx1.append(MyClass.funcion1(i))
            fx2.append(MyClass.funcion2(i))
            
            iteracion.append(i)
            i=i+0.5

        plt.subplot(2,1,1)

        plt.plot(iteracion,fx1,label = "Funcion1")
        plt.plot(iteracion,fx2,label = "funcion2")
        plt.grid(True)
        plt.show()
        
    graficar = staticmethod(graficar)
    
    
j=MyClass.graficar()

# %%
#9.7 B

det|A|
=
$
\begin{pmatrix}
0.5 & -1\\
1.02 & -2
\end{pmatrix}
$ 
=
0.5	 * 	(-2)	 - 	1.02	 * 	(-1)
=
0.02

#9.7 C

Observamos que las funciones pasan muy cerca una de la otra, lo cual al usar el método grafico dificulta hallar la
solución del sistema además visualmente no se puede determinar el punto exacto en el que se intersectan las funciones.

#9.7 D

#multiplicamos la primera ecuacion por (-2) con el fin de eliminar la incognita "y".Entonces tenemos que : 
   -x	 + 	2y =  19.0

1.02x	 - 	2y = -18.8
#-----------
0.02x	 + 	0  = 0.2

# De lo anterior obtenemos el valor de x=10. Reemplazando el valor de x en la primer ecuación nos da: 

0.5*(10)	 - 	y = -9.5

y = 14.5

#9.7 E

#despues de haber modificado el elemento a(11)= 0.52 y haber multiplicado la primera ecuacion por (-2) con el
#fin de eliminar la incognita "y".Entonces tenemos que : 
-1.04x	 + 	2y =  19.0

1.02x	 - 	2y = -18.8
#-----------
-0.02x	 + 	0  = 0.2

# De lo anterior obtenemos el valor de x=-10. Reemplazando el valor de x en la primer ecuación nos da: 

0.52*(-10)	 - 	y = -9.5

y = 4.3

#de lo anterior podemos observar que las funciones comienzan a acercarse mas por el lado negativo, caso contrario de lo que sucedía 
#en el punto 9.7 D, donde si bien las funciones pasaban muy cerca una de la otra , en ese caso la mayor aproximación ocurría en el lado
#positivo.

# %%
#9.8 A

# Matriz Original
$\begin{pmatrix}
10 & 2 & -3 & 27\\
-3 & -6 & 2 & -61.5\\
1  & 1  & 5 & -21.5
\end{pmatrix}
$

#La Fila 1 la divido por 10
$\begin{pmatrix}
1 & 0.2 & -0.3 & 2.7\\
-3 & -6 & 2 & -61.5\\
1  & 1  & 5 & -21.5
\end{pmatrix}
$

#A la Fila 2 le sumo la Fila 1 multiplicada por 3
$\begin{pmatrix}
1 & 0.2 & -0.3 & 2.7\\
0 & -5.4 & 1.1 & -53.4\\
1  & 1  & 5 & -21.5
\end{pmatrix}
$

#A la Fila 3 le sumo la Fila 1 multiplicada por -1
$\begin{pmatrix}
1 & 0.2 & -0.3 & 2.7\\
0 & -5.4 & 1.1 & -53.4\\
0  & 0.8  & 5.3 & -24.2
\end{pmatrix}
$

#La Fila 2 la divido por -5.4
$\begin{pmatrix}
1 & 0.2 & -0.3 & 2.7\\
0 & 1 & -0.2037 & 9.9\\
0  & 0.8  & 5.3 & -24.2
\end{pmatrix}
$

#A la Fila 3 le sumo la Fila 2 multiplicada por -0.8
$\begin{pmatrix}
1 & 0.2 & -0.3 & 2.7\\
0 & 1 & -0.2037 & 9.9\\
0  & 0  & 5.4629 & -32.1
\end{pmatrix}
$

#La Fila 3 la divido por 5.4629
$\begin{pmatrix}
1 & 0.2 & -0.3 & 2.7\\
0 & 1 & -0.2037 & 9.9\\
0  & 0  & 1 & -5.8779
\end{pmatrix}
$

#A la Fila 2 le sumo la Fila 3 multiplicada por 0.2037
$\begin{pmatrix}
1 & 0.2 & -0.3 & 2.7\\
0 & 1 & 0 & 8.6915\\
0  & 0  & 1 & -5.8779
\end{pmatrix}
$

#A la Fila 1 le sumo la Fila 3 multiplicada por 0.3
$\begin{pmatrix}
1 & 0.2 & 0 & 0.9\\
0 & 1 & 0 & 8.6915\\
0  & 0  & 1 & -5.8779
\end{pmatrix}
$

#A la Fila 1 le sumo la Fila 2 multiplicada por -0.2
$\begin{pmatrix}
1 & 0 & 0 & -0.801694\\
0 & 1 & 0 & 8.6915\\
0  & 0  & 1 & -5.8779
\end{pmatrix}
$


#valores de las incognitas:

X1= -0.801694

X2= 8.6915

X3= -5.8779

#9.8 B

10(-0.801694) + 2(8.6915) – (-5.8779) = 27
–3(-0.801694) – 6(8.6915) + 2(-5.8779) = –61.5
(-0.801694) + (8.6915) + 5(-5.8779) = –21.5
