# %%
import math 
import numpy as np
import pylab as pl
from pylab import *
import tkMessageBox

class MyClass(object):
    cadena=""
    funcion1=0.0
    derivada1=0.0
    funcion2=0.0
    derivada2=0.0
    funcion3=0.0
    derivada3=0.0

    x=0.0
    
    def  z(x):
        funcion1=(math.e**x)-1
        return funcion1
    z = staticmethod(z)
    
    def  zz(x):
        derivada1=(math.e**x)
        return derivada1
    zz = staticmethod(zz)
        
    def w(x):
        funcion2=(math.sin(2*x)**3)+(x**2)
        return funcion2
    w = staticmethod(w) 
    
    def ww(x):
        derivada2= (6*(math.sin(2*x)**2)*math.cos(2*x))+(2*x)
        return derivada2
    ww = staticmethod(ww) 
    
    def y(x):
        funcion3=(x**4)+(3*x**2)-math.cos(x)
        return funcion3
    y = staticmethod(y)
    
    def yy(x):
        derivada3=(4*(x**3))+(6*x)+(math.sin(x))
        return derivada3
    yy = staticmethod(yy)
    
    def cal(b):
        
        cont=0 #Guarda Las Ncantidad de valores de X
        i=(-5) 
        j=(-5)
        
        listreal=[]
        listdelante=[]
        listcentro=[]
        listatras=[]
        
        listreal2=[]
        listdelante2=[]
        listcentro2=[]
        listatras2=[]
        
        listreal3=[]
        listdelante3=[]
        listcentro3=[]
        listatras3=[]
    
        while i<=5:
            cont=cont+1
            i+=b
        
        while j<=5:
            
            #------------------------------------------------------------------------------------------------------------------------
            a=j
            x=a-b #equivale a Xi-1
            xi=a#xi
            xii=a+b#Xi+1
            h=b
            #------------------------------------------------------------------------------------------------------------------------
            print "Calculo realizado con X = %.4f"%xi
            mos1=MyClass.zz(x)
            ddelante= (MyClass.z(xii)-MyClass.z(xi))/(xii-xi)
            dcentrada=(MyClass.z(xii)-MyClass.z(x))/(2*h)
            datras=(MyClass.z(xi)-MyClass.z(x))/(xii-xi)
            
            if mos1==0:
                mos1=1
            
            evd=mos1-ddelante #Error verdadero Dif. Delante
            ebvd=abs(evd)# Error Absoluto Verdadero Delante
            erd=evd/mos1# Error relativo Delante
            erpd=abs((evd/mos1)*100)# Error relativo Porcentual Delante
            
            evc=mos1-dcentrada #Error verdadero Dif. centrado
            ebvc=abs(evc)# Error Absoluto Verdadero centrado
            erc=evc/mos1# Error relativo centrado
            erpc=abs((evc/mos1)*100)# Error relativo Porcentual centrado
            
            eva=mos1-datras #Error verdadero Dif. atras
            ebva=abs(eva)# Error Absoluto Verdadero atras
            era=eva/mos1# Error relativo atras
            erpa=abs((eva/mos1)*100)# Error relativo Porcentual atras
            
            listreal.append(mos1)
            listdelante.append(ddelante)
            listcentro.append(dcentrada)
            listatras.append(datras)
            
            cadena = "\n\
    -------------------------------------------------------------------------------------------------\n\
    |                    Funcion: (e^x)-1           Derivada : (e^x)                  \n\
    |-------------------------------------------------------------------------------------------------\n\
    |valor real  : %.7s                       |  Errores [verdadero, absoluto,relativo,retñ.porcen] \n\
    |--------------------------------------------------------------------------------------------------\n\
    |Dif.atras   : %.7s                       |         [%.7s ,%.7s ,%.7s ,%.7s ]                  \n\
    |--------------------------------------------------------------------------------------------------\n\
    |Dif.centrada: %.7s                       |         [%.7s ,%.7s ,%.7s ,%.7s ]                   \n\
    |--------------------------------------------------------------------------------------------------\n\
    |Dif.delante : %.7s                       |         [%.7s ,%.7s ,%.7s ,%.7s ]                   \n\
    |--------------------------------------------------------------------------------------------------\n\
    "% (str(mos1),str(datras),str(eva),str(ebva),str(era),str(erpa),str(dcentrada),str(evc),str(ebvc),str(erc),str(erpc),str(ddelante),str(evd),str(ebvd),str(erd),str(erpd))
            print cadena

            mos2=MyClass.ww(x)
            ddelante= (MyClass.w(xii)-MyClass.w(xi))/(xii-xi)
            dcentrada=(MyClass.w(xii)-MyClass.w(x))/(2*h)
            datras=(MyClass.w(xi)-MyClass.w(x))/(xii-xi)   
            
            if mos2==0:
                mos2=1
            
            evd=mos2-ddelante #Error verdadero Dif. Delante
            ebvd=abs(evd)# Error Absoluto Verdadero Delante
            erd=evd/mos2# Error relativo Delante
            erpd=abs((evd/mos2)*100)# Error relativo Porcentual Delante
            
            evc=mos2-dcentrada #Error verdadero Dif. centrado
            ebvc=abs(evc)# Error Absoluto Verdadero centrado
            erc=evc/mos2# Error relativo centrado
            erpc=abs((evc/mos2)*100)# Error relativo Porcentual centrado
            
            eva=mos2-datras #Error verdadero Dif. atras
            ebva=abs(eva)# Error Absoluto Verdadero atras
            era=eva/mos2# Error relativo atras
            erpa=abs((eva/mos2)*100)# Error relativo Porcentual atras
            
            listreal2.append(mos2)
            listdelante2.append(ddelante)
            listcentro2.append(dcentrada)
            listatras2.append(datras)

            cadena = "\n\
    ---------------------------------------------------------------------------------------------------\n\
    |               Funcion: sen(2x)^3 + x^2      Derivada:3sen(2x)*sen(4x)                        \n\
    |-------------------------------------------------------------------------------------------------\n\
    |valor real  : %.7s                       |  Errores [verdadero, absoluto,relativo,retñ.porcen] \n\
    |--------------------------------------------------------------------------------------------------\n\
    |Dif.atras   : %.7s                       |         [%.7s ,%.7s ,%.7s ,%.7s ]                  \n\
    |--------------------------------------------------------------------------------------------------\n\
    |Dif.centrada: %.7s                       |         [%.7s ,%.7s ,%.7s ,%.7s ]                   \n\
    |--------------------------------------------------------------------------------------------------\n\
    |Dif.delante : %.7s                       |         [%.7s ,%.7s ,%.7s ,%.7s ]                   \n\
    |--------------------------------------------------------------------------------------------------\n\
    "% (str(mos2),str(datras),str(eva),str(ebva),str(era),str(erpa),str(dcentrada),str(evc),str(ebvc),str(erc),str(erpc),str(ddelante),str(evd),str(ebvd),str(erd),str(erpd))

            print cadena

            mos3=MyClass.yy(x)
            ddelante= (MyClass.y(xii)-MyClass.y(xi))/(xii-xi)
            dcentrada=(MyClass.y(xii)-MyClass.y(x))/(2*h)
            datras=(MyClass.y(xi)-MyClass.y(x))/(xii-xi)
            
            if mos3==0:
                mos3=1
            
            evd=mos3-ddelante #Error verdadero Dif. Delante
            ebvd=abs(evd)# Error Absoluto Verdadero Delante
            erd=evd/mos3# Error relativo Delante
            erpd=abs((evd/mos3)*100)# Error relativo Porcentual Delante
            
            evc=mos3-dcentrada #Error verdadero Dif. centrado
            ebvc=abs(evc)# Error Absoluto Verdadero centrado
            erc=evc/mos3# Error relativo centrado
            erpc=abs((evc/mos3)*100)# Error relativo Porcentual centrado
            
            eva=mos3-datras #Error verdadero Dif. atras
            ebva=abs(eva)# Error Absoluto Verdadero atras
            era=eva/mos3# Error relativo atras
            erpa=abs((eva/mos3)*100)# Error relativo Porcentual atras
            
            listreal3.append(mos3)
            listdelante3.append(ddelante)
            listcentro3.append(dcentrada)
            listatras3.append(datras)

            cadena = "\n\
    -------------------------------------------------------------------------------------------------\n\
    |             Funcion: x^4 +3x^2 + cos(x)      Derivada: 4x^3 +6x + sen(x)                \n\
    |-------------------------------------------------------------------------------------------------\n\
    |valor real  : %.7s                       |  Errores [verdadero, absoluto,relativo,retñ.porcen] \n\
    |--------------------------------------------------------------------------------------------------\n\
    |Dif.atras   : %.7s                       |         [%.7s ,%.7s ,%.7s ,%.7s ]                  \n\
    |--------------------------------------------------------------------------------------------------\n\
    |Dif.centrada: %.7s                       |         [%.7s ,%.7s ,%.7s ,%.7s ]                   \n\
    |--------------------------------------------------------------------------------------------------\n\
    |Dif.delante : %.7s                       |         [%.7s ,%.7s ,%.7s ,%.7s ]                   \n\
    |--------------------------------------------------------------------------------------------------\n\
    "% (str(mos2),str(datras),str(eva),str(ebva),str(era),str(erpa),str(dcentrada),str(evc),str(ebvc),str(erc),str(erpc),str(ddelante),str(evd),str(ebvd),str(erd),str(erpd))

            print cadena
            
            j=j+h
        #---------------------------------------------------------------------------------------------------------------------
        tkMessageBox.showinfo(title="Informacion", message="Las Grafica expresan el comportamiento de la función en los N valores que toma “x”, cada valor se almaceno en un vector el cuan se graficara continuacióNt: Algunas funciones toman valores muy grandes por tanto se graficara una sección de ella")
        #---------------------------------------------------------------------------------------------------------------------    
        pl.plot(listreal)
        pl.plot(listdelante)
        pl.plot(listcentro)
        pl.plot(listatras)
        pl.title("Aprox de derivadas por dif finitas")
        pl.ylabel("Comportamiento de la funcion en el tiemo")
        pl.xlabel(" Funcion: (e^x)-1           Derivada : (e^x) ")
        
        plt.plot(listreal, label = "Valor Real")
        plt.plot(listdelante, label = "Dif.delante")
        plt.plot(listcentro, label = "Dif.centrada")
        plt.plot(listatras, label = "Dif.atras")
        plt.legend()
        plt.legend(loc="upper left") 
        pl.show()
        #----------------------------------------------------------------------------------------------------------------------
        pl.plot(listreal2)
        pl.plot(listdelante2)
        pl.plot(listcentro2)
        pl.plot(listatras2)
        pl.title("Aprox de derivadas por dif finitas")
        pl.ylabel("Comportamiento de la funcion en el tiemo")
        pl.xlabel("Funcion: sen(2x)^3 + x^2      Derivada:3sen(2x)*sen(4x)")
        
        plt.plot(listreal2, label = "Valor Real")
        plt.plot(listdelante2, label = "Dif.delante")
        plt.plot(listcentro2, label = "Dif.centrada")
        plt.plot(listatras2, label = "Dif.atras")
        plt.legend()
        plt.legend(loc="upper left") 
        pl.show()
        #---------------------------------------------------------------------------------------------------------------------
        pl.plot(listreal3)
        pl.plot(listdelante3)
        pl.plot(listcentro3)
        pl.plot(listatras3)
        pl.title("Aprox de derivadas por dif finitas")
        pl.ylabel("Comportamiento de la funcion en el tiemo")
        pl.xlabel("Funcion: x^4 +3x^2 + cos(x)      Derivada: (6*(math.sin(2*x)**2)*math.cos(2*x))+(2*x)")
        
        
        plt.plot(listreal3, label = "Valor Real")
        plt.plot(listdelante3, label = "Dif.delante")
        plt.plot(listcentro3, label = "Dif.centrada")
        plt.plot(listatras3, label = "Dif.atras")
        plt.legend()
        plt.legend(loc="upper left") 
        pl.show()
        #----------------------------------------------------------------------------------------------------------------------
        print listreal3
        print listdelante3
        print listcentro3
        print listatras3
    cal = staticmethod(cal)

valor=input ("Ingrese cantidad: ")
j=MyClass.cal(valor)
# Out:
# Ingrese cantidad: 0.02
# Calculo realizado con X = -5.0000
#
#     -------------------------------------------------------------------------------------------------
#     |                    Funcion: (e^x)-1           Derivada : (e^x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : 0.00660                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : 0.00667                       |         [-6.6487 ,6.64877 ,-0.0100 ,1.00670 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: 0.00673                       |         [-0.0001 ,0.00013 ,-0.0202 ,2.02693 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : 0.00680                       |         [-0.0002 ,0.00020 ,-0.0304 ,3.04717 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     ---------------------------------------------------------------------------------------------------
#     |               Funcion: sen(2x)^3 + x^2      Derivada:3sen(2x)*sen(4x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -11.672                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -11.581                       |         [-0.0905 ,0.09050 ,0.00775 ,0.77542 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -11.489                       |         [-0.1830 ,0.18300 ,0.01567 ,1.56789 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -11.396                       |         [-0.2755 ,0.27550 ,0.02360 ,2.36036 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------
#     |             Funcion: x^4 +3x^2 + cos(x)      Derivada: 4x^3 +6x + sen(x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -11.672                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -532.11                       |         [-3.0789 ,3.07898 ,0.00575 ,0.57530 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -529.04                       |         [-6.1418 ,6.14183 ,0.01147 ,1.14759 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -525.98                       |         [-9.2046 ,9.20467 ,0.01719 ,1.71988 ]
#     |--------------------------------------------------------------------------------------------------
#
# Calculo realizado con X = -4.9800
#
#     -------------------------------------------------------------------------------------------------
#     |                    Funcion: (e^x)-1           Derivada : (e^x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : 0.00673                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : 0.00680                       |         [-6.7830 ,6.78309 ,-0.0100 ,1.00670 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: 0.00687                       |         [-0.0001 ,0.00013 ,-0.0202 ,2.02693 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : 0.00694                       |         [-0.0002 ,0.00020 ,-0.0304 ,3.04717 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     ---------------------------------------------------------------------------------------------------
#     |               Funcion: sen(2x)^3 + x^2      Derivada:3sen(2x)*sen(4x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -11.489                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -11.396                       |         [-0.0933 ,0.09338 ,0.00812 ,0.81277 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -11.302                       |         [-0.1879 ,0.18792 ,0.01635 ,1.63556 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -11.207                       |         [-0.2824 ,0.28246 ,0.02458 ,2.45836 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------
#     |             Funcion: x^4 +3x^2 + cos(x)      Derivada: 4x^3 +6x + sen(x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -11.489                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -525.98                       |         [-3.0547 ,3.05478 ,0.00577 ,0.57741 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -522.94                       |         [-6.0934 ,6.09348 ,0.01151 ,1.15179 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -519.90                       |         [-9.1321 ,9.13218 ,0.01726 ,1.72617 ]
#     |--------------------------------------------------------------------------------------------------
#
# Calculo realizado con X = -4.9600
#
#     -------------------------------------------------------------------------------------------------
#     |                    Funcion: (e^x)-1           Derivada : (e^x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : 0.00687                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : 0.00694                       |         [-6.9201 ,6.92011 ,-0.0100 ,1.00670 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: 0.00701                       |         [-0.0001 ,0.00013 ,-0.0202 ,2.02693 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : 0.00708                       |         [-0.0002 ,0.00020 ,-0.0304 ,3.04717 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     ---------------------------------------------------------------------------------------------------
#     |               Funcion: sen(2x)^3 + x^2      Derivada:3sen(2x)*sen(4x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -11.302                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -11.207                       |         [-0.0950 ,0.09500 ,0.00840 ,0.84059 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -11.112                       |         [-0.1903 ,0.19031 ,0.01683 ,1.68386 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -11.016                       |         [-0.2856 ,0.28563 ,0.02527 ,2.52714 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------
#     |             Funcion: x^4 +3x^2 + cos(x)      Derivada: 4x^3 +6x + sen(x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -11.302                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -519.90                       |         [-3.0306 ,3.03066 ,0.00579 ,0.57954 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -516.89                       |         [-6.0453 ,6.04531 ,0.01156 ,1.15602 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -513.87                       |         [-9.0599 ,9.05996 ,0.01732 ,1.73250 ]
#     |--------------------------------------------------------------------------------------------------
#
# Calculo realizado con X = -4.9400
#
#     -------------------------------------------------------------------------------------------------
#     |                    Funcion: (e^x)-1           Derivada : (e^x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : 0.00701                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : 0.00708                       |         [-7.0599 ,7.05991 ,-0.0100 ,1.00670 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: 0.00715                       |         [-0.0001 ,0.00014 ,-0.0202 ,2.02693 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : 0.00722                       |         [-0.0002 ,0.00021 ,-0.0304 ,3.04717 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     ---------------------------------------------------------------------------------------------------
#     |               Funcion: sen(2x)^3 + x^2      Derivada:3sen(2x)*sen(4x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -11.112                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -11.016                       |         [-0.0953 ,0.09535 ,0.00858 ,0.85813 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -10.922                       |         [-0.1901 ,0.19017 ,0.01711 ,1.71141 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -10.827                       |         [-0.2849 ,0.28499 ,0.02564 ,2.56470 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------
#     |             Funcion: x^4 +3x^2 + cos(x)      Derivada: 4x^3 +6x + sen(x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -11.112                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -513.87                       |         [-3.0066 ,3.00665 ,0.00581 ,0.58168 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -510.88                       |         [-5.9973 ,5.99734 ,0.01160 ,1.16028 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -507.89                       |         [-8.9880 ,8.98804 ,0.01738 ,1.73888 ]
#     |--------------------------------------------------------------------------------------------------
#
# Calculo realizado con X = -4.9200
#
#     -------------------------------------------------------------------------------------------------
#     |                    Funcion: (e^x)-1           Derivada : (e^x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : 0.00715                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : 0.00722                       |         [-7.2025 ,7.20253 ,-0.0100 ,1.00670 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: 0.00729                       |         [-0.0001 ,0.00014 ,-0.0202 ,2.02693 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : 0.00737                       |         [-0.0002 ,0.00021 ,-0.0304 ,3.04717 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     ---------------------------------------------------------------------------------------------------
#     |               Funcion: sen(2x)^3 + x^2      Derivada:3sen(2x)*sen(4x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -10.921                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -10.827                       |         [-0.0944 ,0.09444 ,0.00864 ,0.86475 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -10.734                       |         [-0.1875 ,0.18752 ,0.01717 ,1.71702 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -10.641                       |         [-0.2806 ,0.28061 ,0.02569 ,2.56929 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------
#     |             Funcion: x^4 +3x^2 + cos(x)      Derivada: 4x^3 +6x + sen(x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -10.921                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -507.89                       |         [-2.9827 ,2.98272 ,0.00583 ,0.58384 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -504.93                       |         [-5.9495 ,5.94956 ,0.01164 ,1.16456 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -501.96                       |         [-8.9164 ,8.91640 ,0.01745 ,1.74529 ]
#     |--------------------------------------------------------------------------------------------------
#
# Calculo realizado con X = -4.9000
#
#     -------------------------------------------------------------------------------------------------
#     |                    Funcion: (e^x)-1           Derivada : (e^x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : 0.00729                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : 0.00737                       |         [-7.3480 ,7.34803 ,-0.0100 ,1.00670 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: 0.00744                       |         [-0.0001 ,0.00014 ,-0.0202 ,2.02693 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : 0.00752                       |         [-0.0002 ,0.00022 ,-0.0304 ,3.04717 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     ---------------------------------------------------------------------------------------------------
#     |               Funcion: sen(2x)^3 + x^2      Derivada:3sen(2x)*sen(4x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -10.733                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -10.641                       |         [-0.0922 ,0.09229 ,0.00859 ,0.85992 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -10.550                       |         [-0.1824 ,0.18243 ,0.01699 ,1.69973 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -10.460                       |         [-0.2725 ,0.27257 ,0.02539 ,2.53953 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------
#     |             Funcion: x^4 +3x^2 + cos(x)      Derivada: 4x^3 +6x + sen(x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -10.733                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -501.96                       |         [-2.9588 ,2.95889 ,0.00586 ,0.58600 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -499.02                       |         [-5.9019 ,5.90197 ,0.01168 ,1.16888 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -496.07                       |         [-8.8450 ,8.84504 ,0.01751 ,1.75175 ]
#     |--------------------------------------------------------------------------------------------------
#
# Calculo realizado con X = -4.8800
#
#     -------------------------------------------------------------------------------------------------
#     |                    Funcion: (e^x)-1           Derivada : (e^x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : 0.00744                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : 0.00752                       |         [-7.4964 ,7.49647 ,-0.0100 ,1.00670 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: 0.00759                       |         [-0.0001 ,0.00015 ,-0.0202 ,2.02693 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : 0.00767                       |         [-0.0002 ,0.00022 ,-0.0304 ,3.04717 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     ---------------------------------------------------------------------------------------------------
#     |               Funcion: sen(2x)^3 + x^2      Derivada:3sen(2x)*sen(4x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -10.549                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -10.460                       |         [-0.0889 ,0.08896 ,0.00843 ,0.84326 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -10.374                       |         [-0.1750 ,0.17501 ,0.01658 ,1.65890 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -10.288                       |         [-0.2610 ,0.26105 ,0.02474 ,2.47453 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------
#     |             Funcion: x^4 +3x^2 + cos(x)      Derivada: 4x^3 +6x + sen(x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -10.549                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -496.07                       |         [-2.9351 ,2.93516 ,0.00588 ,0.58819 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -493.15                       |         [-5.8545 ,5.85457 ,0.01173 ,1.17322 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -490.23                       |         [-8.7739 ,8.77397 ,0.01758 ,1.75826 ]
#     |--------------------------------------------------------------------------------------------------
#
# Calculo realizado con X = -4.8600
#
#     -------------------------------------------------------------------------------------------------
#     |                    Funcion: (e^x)-1           Derivada : (e^x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : 0.00759                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : 0.00767                       |         [-7.6479 ,7.64791 ,-0.0100 ,1.00670 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: 0.00775                       |         [-0.0001 ,0.00015 ,-0.0202 ,2.02693 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : 0.00782                       |         [-0.0002 ,0.00023 ,-0.0304 ,3.04717 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     ---------------------------------------------------------------------------------------------------
#     |               Funcion: sen(2x)^3 + x^2      Derivada:3sen(2x)*sen(4x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -10.373                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -10.288                       |         [-0.0844 ,0.08449 ,0.00814 ,0.81458 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -10.207                       |         [-0.1653 ,0.16537 ,0.01594 ,1.59427 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -10.126                       |         [-0.2462 ,0.24625 ,0.02373 ,2.37397 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------
#     |             Funcion: x^4 +3x^2 + cos(x)      Derivada: 4x^3 +6x + sen(x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -10.373                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -490.23                       |         [-2.9115 ,2.91153 ,0.00590 ,0.59039 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -487.34                       |         [-5.8073 ,5.80736 ,0.01177 ,1.17760 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -484.44                       |         [-8.7031 ,8.70319 ,0.01764 ,1.76481 ]
#     |--------------------------------------------------------------------------------------------------
#
# Calculo realizado con X = -4.8400
#
#     -------------------------------------------------------------------------------------------------
#     |                    Funcion: (e^x)-1           Derivada : (e^x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : 0.00775                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : 0.00782                       |         [-7.8024 ,7.80241 ,-0.0100 ,1.00670 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: 0.00790                       |         [-0.0001 ,0.00015 ,-0.0202 ,2.02693 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : 0.00798                       |         [-0.0002 ,0.00023 ,-0.0304 ,3.04717 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     ---------------------------------------------------------------------------------------------------
#     |               Funcion: sen(2x)^3 + x^2      Derivada:3sen(2x)*sen(4x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -10.205                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -10.126                       |         [-0.0789 ,0.07898 ,0.00773 ,0.77391 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -10.052                       |         [-0.1537 ,0.15370 ,0.01506 ,1.50607 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -9.9775                       |         [-0.2284 ,0.22843 ,0.02238 ,2.23823 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------
#     |             Funcion: x^4 +3x^2 + cos(x)      Derivada: 4x^3 +6x + sen(x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -10.205                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -484.44                       |         [-2.8879 ,2.88798 ,0.00592 ,0.59260 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -481.57                       |         [-5.7603 ,5.76034 ,0.01182 ,1.18200 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -478.70                       |         [-8.6326 ,8.63269 ,0.01771 ,1.77140 ]
#     |--------------------------------------------------------------------------------------------------
#
# Calculo realizado con X = -4.8200
#
#     -------------------------------------------------------------------------------------------------
#     |                    Funcion: (e^x)-1           Derivada : (e^x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : 0.00790                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : 0.00798                       |         [-7.9600 ,7.96003 ,-0.0100 ,1.00670 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: 0.00806                       |         [-0.0001 ,0.00016 ,-0.0202 ,2.02693 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : 0.00814                       |         [-0.0002 ,0.00024 ,-0.0304 ,3.04717 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     ---------------------------------------------------------------------------------------------------
#     |               Funcion: sen(2x)^3 + x^2      Derivada:3sen(2x)*sen(4x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -10.050                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -9.9775                       |         [-0.0725 ,0.07251 ,0.00721 ,0.72156 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -9.9098                       |         [-0.1402 ,0.14020 ,0.01395 ,1.39504 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -9.8421                       |         [-0.2078 ,0.20788 ,0.02068 ,2.06852 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------
#     |             Funcion: x^4 +3x^2 + cos(x)      Derivada: 4x^3 +6x + sen(x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -10.050                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -478.70                       |         [-2.8645 ,2.86454 ,0.00594 ,0.59483 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -475.85                       |         [-5.7135 ,5.71351 ,0.01186 ,1.18644 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -473.00                       |         [-8.5624 ,8.56248 ,0.01778 ,1.77804 ]
#     |--------------------------------------------------------------------------------------------------
#
# Calculo realizado con X = -4.8000
#
#     -------------------------------------------------------------------------------------------------
#     |                    Funcion: (e^x)-1           Derivada : (e^x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : 0.00806                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : 0.00814                       |         [-8.1208 ,8.12083 ,-0.0100 ,1.00670 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: 0.00823                       |         [-0.0001 ,0.00016 ,-0.0202 ,2.02693 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : 0.00831                       |         [-0.0002 ,0.00024 ,-0.0304 ,3.04717 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     ---------------------------------------------------------------------------------------------------
#     |               Funcion: sen(2x)^3 + x^2      Derivada:3sen(2x)*sen(4x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -9.9073                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -9.8421                       |         [-0.0652 ,0.06520 ,0.00658 ,0.65811 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -9.7822                       |         [-0.1250 ,0.12507 ,0.01262 ,1.26249 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -9.7223                       |         [-0.1849 ,0.18495 ,0.01866 ,1.86687 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------
#     |             Funcion: x^4 +3x^2 + cos(x)      Derivada: 4x^3 +6x + sen(x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -9.9073                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -473.00                       |         [-2.8411 ,2.84119 ,0.00597 ,0.59708 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -470.17                       |         [-5.6668 ,5.66687 ,0.01190 ,1.19090 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -467.35                       |         [-8.4925 ,8.49255 ,0.01784 ,1.78472 ]
#     |--------------------------------------------------------------------------------------------------
#
# Calculo realizado con X = -4.7800
#
#     -------------------------------------------------------------------------------------------------
#     |                    Funcion: (e^x)-1           Derivada : (e^x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : 0.00822                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : 0.00831                       |         [-8.2848 ,8.28488 ,-0.0100 ,1.00670 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: 0.00839                       |         [-0.0001 ,0.00016 ,-0.0202 ,2.02693 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : 0.00848                       |         [-0.0002 ,0.00025 ,-0.0304 ,3.04717 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     ---------------------------------------------------------------------------------------------------
#     |               Funcion: sen(2x)^3 + x^2      Derivada:3sen(2x)*sen(4x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -9.7795                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -9.7223                       |         [-0.0571 ,0.05715 ,0.00584 ,0.58448 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -9.6709                       |         [-0.1085 ,0.10859 ,0.01110 ,1.11038 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -9.6195                       |         [-0.1600 ,0.16002 ,0.01636 ,1.63627 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------
#     |             Funcion: x^4 +3x^2 + cos(x)      Derivada: 4x^3 +6x + sen(x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -9.7795                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -467.35                       |         [-2.8179 ,2.81793 ,0.00599 ,0.59934 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -464.55                       |         [-5.6204 ,5.62042 ,0.01195 ,1.19539 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -461.74                       |         [-8.4229 ,8.42291 ,0.01791 ,1.79145 ]
#     |--------------------------------------------------------------------------------------------------
#
# Calculo realizado con X = -4.7600
#
#     -------------------------------------------------------------------------------------------------
#     |                    Funcion: (e^x)-1           Derivada : (e^x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : 0.00839                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : 0.00848                       |         [-8.4522 ,8.45225 ,-0.0100 ,1.00670 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: 0.00856                       |         [-0.0001 ,0.00017 ,-0.0202 ,2.02693 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : 0.00865                       |         [-0.0002 ,0.00025 ,-0.0304 ,3.04717 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     ---------------------------------------------------------------------------------------------------
#     |               Funcion: sen(2x)^3 + x^2      Derivada:3sen(2x)*sen(4x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -9.6680                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -9.6195                       |         [-0.0485 ,0.04852 ,0.00501 ,0.50187 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -9.5770                       |         [-0.0910 ,0.09100 ,0.00941 ,0.94125 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -9.5345                       |         [-0.1334 ,0.13347 ,0.01380 ,1.38062 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------
#     |             Funcion: x^4 +3x^2 + cos(x)      Derivada: 4x^3 +6x + sen(x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -9.6680                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : -461.74                       |         [-2.7947 ,2.79477 ,0.00601 ,0.60161 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: -458.96                       |         [-5.5741 ,5.57417 ,0.01199 ,1.19992 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : -456.19                       |         [-8.3535 ,8.35356 ,0.01798 ,1.79823 ]
#     |--------------------------------------------------------------------------------------------------
#
# Calculo realizado con X = -4.7400
#
#     -------------------------------------------------------------------------------------------------
#     |                    Funcion: (e^x)-1           Derivada : (e^x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : 0.00856                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.atras   : 0.00865                       |         [-8.6230 ,8.62300 ,-0.0100 ,1.00670 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.centrada: 0.00873                       |         [-0.0001 ,0.00017 ,-0.0202 ,2.02693 ]
#     |--------------------------------------------------------------------------------------------------
#     |Dif.delante : 0.00882                       |         [-0.0002 ,0.00026 ,-0.0304 ,3.04717 ]
#     |--------------------------------------------------------------------------------------------------
#
#
#     ---------------------------------------------------------------------------------------------------
#     |               Funcion: sen(2x)^3 + x^2      Derivada:3sen(2x)*sen(4x)
#     |-------------------------------------------------------------------------------------------------
#     |valor real  : -9.5739                       |  Errores [verdadero, absoluto,relativo,retñ.porcen]
#     |--------------------------------------------------------------------------------------------------
# ...
# [-525.9862951250396, -519.9088947363745, -513.8795931288992, -507.8982002632239, -501.9645259444296, -496.07837982139165, -490.23957138608034, -484.447909973061, -478.70320475884, -473.0052647614785, -467.35389884014324, -461.7489156947768, -456.1901238658249, -450.6773317339974, -445.21034752014924, -439.7889792851609, -434.41303492992705, -429.082322195402, -423.79664866269076, -418.5558217532194, -413.35964872899666, -408.20793669284416, -403.1004925888141, -398.037123202593, -393.0176351619819, -388.0418349374364, -383.10952884272035, -378.220523035517, -373.37462351823035, -368.5716361387272, -363.81136659123774, -359.0936204172712, -354.418203006576, -349.78491959821446, -345.19357528163704, -340.6439749978846, -336.1359235407705, -331.6692255581884, -327.24368555345353, -322.85910788668394, -318.51529677627576, -314.21205630040095, -309.94919039858735, -305.7265028733306, -301.54379739179905, -297.40087748751375, -293.29754656220985, -289.23360788759896, -285.2088646073217, -281.2231197388573, -277.2761761755189, -273.3678366885042, -269.49790392899024, -265.666180430267, -261.872468609914, -258.1165707720485, -254.39828910960193, -250.7174257066365, -247.07378254071534, -243.46716148530425, -239.89736431223585, -236.36419269419642, -232.86744820723564, -229.40693233337137, -225.98244646317747, -222.59379189841846, -219.24076985475247, -215.92318146441707, -212.6408277790089, -209.39350977223492, -206.181028342729, -203.0031843169068, -199.85977845181947, -196.7506114380596, -193.67548390266745, -190.63419641211948, -187.62654947525147, -184.6523435462954, -181.71137902787092, -178.80345627404478, -175.92837559337354, -173.08593725198577, -170.2759414766787, -167.49818845802181, -164.7524783534847, -162.0386112905733, -159.35638736997205, -156.70560666871424, -154.08606924335103, -151.49757513310917, -148.9399243631054, -146.41291694750848, -143.9163528927543, -141.45003220073338, -139.01375487198482, -136.60732090890934, -134.2305303189568, -131.8831831178321, -129.56507933267918, -127.27601900527634, -125.01580219522299, -122.7842289831037, -120.5810994736679, -118.40621379898256, -116.25937212157699, -114.14037463758352, -112.04902157985249, -109.98511322106798, -107.94844987682798, -105.93883190872465, -103.95605972739821, -101.99993379557233, -100.07025463106905, -98.16682280980365, -96.28943896874623, -94.43790380888109, -92.61201809810862, -90.81158267415495, -89.03639844742548, -87.28626640384427, -85.56098760766126, -83.86036320421965, -82.18419442271056, -80.5322825788685, -78.90442907764943, -77.30043541587179, -75.72010318481361, -74.16323407277716, -72.62962986761636, -71.1190924592134, -69.6314238419354, -68.16642611702365, -66.72390149496218, -65.30365229778917, -63.90548096136749, -62.52919003761542, -61.17458219667847, -59.84146022906773, -58.529627047738536, -57.23888569013051, -55.96903932014671, -54.719891230092394, -53.491244842556135, -52.28290371224164, -51.09467152774303, -49.92635211327641, -48.77774943033919, -47.64866757933546, -46.53891080113186, -45.44828347855883, -44.37659013786237, -43.323635450089135, -42.289224232420395, -41.27316144944434, -40.275252214370525, -39.29530179018471, -38.33311559074165, -37.38849918180268, -36.461258282008444, -35.55119876378822, -34.65812665421592, -33.781848135795805, -32.922169547190954, -32.07889738388673, -31.251838298792627, -30.440799102783494, -29.64558676517128, -28.86600841412059, -28.10187133699535, -27.352982980644722, -26.619150951624857, -25.90018301635444, -25.19588710121068, -24.506071292556243, -23.83054383670682, -23.169113139830944, -22.52158776778861, -21.887776445904343, -21.267488058677646, -20.660531649428364, -20.06671641988012, -19.485851729679897, -18.917747095852526, -18.362212192196186, -17.81905684861121, -17.288091050368934, -16.769124937317176, -16.261968803024757, -15.766433093863993, -15.282328408031795, -14.809465494510864, -14.347655251970025, -13.896708727604633, -13.456437115918161, -13.026651757443585, -12.607164137408 ...
# [-529.0491396523294, -522.9475949306959, -516.8942439326258, -510.88889669605067, -504.931363103816, -499.0214528829, -493.1589756037255, -487.34374067956026, -481.5755573659402, -475.8542347601491, -470.17958180080086, -464.55140726745014, -458.9695197802911, -453.4337277999015, -447.94383962706377, -442.49966340264564, -437.10100710753466, -431.7476785626553, -426.4394854290373, -421.1762352079461, -415.95773524109916, -410.78379271091165, -405.6542146408205, -400.56880789569504, -395.52737918227905, -390.52973504970083, -385.57568189007014, -380.66502593911054, -375.79757327686565, -370.97312982847086, -366.19150136497467, -361.4524935042468, -356.755911711916, -352.1015613023877, -347.48924743991836, -342.9187751397535, -338.3899492693203, -333.9025745494723, -329.45645555581393, -325.0513967200618, -320.68720233147303, -316.3636765383316, -312.0806233494875, -307.8378466359524, -303.63515013255835, -299.47233743965, -295.3492120248555, -291.2655772248982, -287.2212362474542, -283.21599217308346, -279.24964795718523, -275.3220064320118, -271.43287030874745, -267.58204217962884, -263.7693245200907, -259.99451969098146, -256.25742994082543, -252.55785740811945, -248.89560412367615, -245.27047201301002, -241.68226289877026, -238.13077850321633, -234.61582045071623, -231.1371902703037, -227.69468939827462, -224.28811918079816, -220.91728087658566, -217.58197565958497, -214.28200462171318, -211.0171687756221, -207.78726905748215, -204.59210632981808, -201.4314813843633, -198.3051949449397, -195.2130476703637, -192.15484015739364, -189.13037294368564, -186.1394465107736, -183.18186128708334, -180.25741765095802, -177.36591593370932, -174.5071564226798, -171.68093936433237, -168.8870649673504, -166.1253334057534, -163.39554482202914, -160.69749933027282, -158.0309970193433, -155.39583795603278, -152.79182218823024, -150.21874974810743, -147.67642065530708, -145.1646349201315, -142.68319254674395, -140.2318935363592, -137.8105378904472, -135.41892561393317, -133.05685671839456, -130.72413122525575, -128.42054916897786, -126.14591060024978, -123.90001558916346, -121.68266422838592, -119.49365663632534, -117.33279296027987, -115.19987337958035, -113.0946981087181, -111.01706740046033, -108.96678154894808, -106.94364089277641, -104.94744581806152, -102.97799676148536, -101.03509421332078, -99.11853872043643, -97.22813088927502, -95.36367138881374, -93.52496095349494, -91.71180038613187, -89.9239905607903, -88.16133242563495, -86.42362700575283, -84.71067540594052, -83.02227881346518, -81.3582385007896, -79.71835582825904, -78.10243224676067, -76.51026930034277, -74.94166862879545, -73.39643197019683, -71.87436116341495, -70.37525815057445, -68.89892497947957, -67.44516380599296, -66.01377689637573, -64.60456662957839, -63.21733549949151, -61.851886117147004, -60.50802121287315, -59.18554363840318, -57.88425636893457, -56.60396250513866, -55.3444652751196, -54.105568036324314, -52.88707427739894, -51.68878761999238, -50.51051182050976, -49.35205077180784, -48.21320850483737, -47.0937891902337, -45.993597139845384, -44.91243680821064, -43.85011279397579, -42.8064298412548, -41.7811928409324, -40.77420683190746, -39.78527700227765, -38.81420869046321, -37.8608073862722, -36.924878731905594, -36.00622852289836, -35.1046627090021, -34.21998739500589, -33.35200884149341, -32.50053346553887, -31.66536784133971, -30.84631870078809, -30.043192933977412, -29.255797589645958, -28.483939875557994, -27.72742715882006, -26.986066966134814, -26.25966698398967, -25.54803505878258, -24.850979196883483, -24.16830756463155, -23.499828488268903, -22.845350453809797, -22.204682106846494, -21.57763225229101, -20.96400985405302, -20.363624034654258, -19.776284074780026, -19.201799412766228, -18.639979644024372, -18.090634520403714, -17.553573949490087, -17.02860799384307, -16.515546870170983, -16.01420094844439, -15.524380750947907, -15.045896951271342, -14.578560373240457, -14.122181989787341, -13.676572921761409, -13.241544436680885, -12.81690794742607,  ...
# [-532.1119841796417, -525.9862951250396, -519.9088947363745, -513.8795931288992, -507.8982002632239, -501.9645259444296, -496.07837982139165, -490.23957138608034, -484.447909973061, -478.70320475884, -473.0052647614785, -467.35389884014324, -461.7489156947768, -456.1901238658249, -450.6773317339974, -445.21034752014924, -439.7889792851609, -434.41303492992705, -429.082322195402, -423.79664866269076, -418.5558217532194, -413.35964872899666, -408.20793669284416, -403.1004925888141, -398.037123202593, -393.0176351619819, -388.0418349374364, -383.10952884272035, -378.220523035517, -373.37462351823035, -368.5716361387272, -363.81136659123774, -359.0936204172712, -354.418203006576, -349.78491959821446, -345.19357528163704, -340.6439749978846, -336.1359235407705, -331.6692255581884, -327.24368555345353, -322.85910788668394, -318.51529677627576, -314.21205630040095, -309.94919039858735, -305.7265028733306, -301.54379739179905, -297.40087748751375, -293.29754656220985, -289.23360788759896, -285.2088646073217, -281.2231197388511, -277.2761761755189, -273.3678366885042, -269.49790392899024, -265.666180430267, -261.872468609914, -258.1165707720485, -254.39828910960193, -250.7174257066365, -247.07378254071534, -243.46716148530425, -239.89736431223585, -236.36419269419642, -232.86744820723564, -229.40693233337137, -225.98244646317747, -222.59379189841846, -219.24076985475247, -215.92318146441707, -212.6408277790089, -209.39350977223492, -206.181028342729, -203.0031843169068, -199.85977845181947, -196.7506114380596, -193.67548390266745, -190.63419641211948, -187.62654947525147, -184.6523435462954, -181.71137902787092, -178.80345627404478, -175.92837559337354, -173.08593725198577, -170.2759414766787, -167.49818845802181, -164.7524783534847, -162.0386112905733, -159.35638736997205, -156.70560666871424, -154.08606924335103, -151.49757513310917, -148.9399243631054, -146.41291694750848, -143.9163528927543, -141.45003220073338, -139.01375487198482, -136.60732090890934, -134.2305303189568, -131.8831831178321, -129.56507933267918, -127.27601900527634, -125.01580219522299, -122.7842289831037, -120.5810994736679, -118.40621379898256, -116.25937212157699, -114.14037463758352, -112.04902157985249, -109.98511322106798, -107.94844987682798, -105.93883190872465, -103.95605972739821, -101.99993379557233, -100.07025463106905, -98.16682280980365, -96.28943896874623, -94.43790380888109, -92.61201809810862, -90.81158267415495, -89.03639844742548, -87.28626640384427, -85.56098760766126, -83.86036320421965, -82.18419442271056, -80.5322825788685, -78.90442907764943, -77.30043541587179, -75.72010318481361, -74.16323407277716, -72.62962986761636, -71.1190924592134, -69.6314238419354, -68.16642611702365, -66.72390149496218, -65.30365229778917, -63.90548096136749, -62.52919003761542, -61.17458219667847, -59.84146022906773, -58.529627047738536, -57.23888569013051, -55.96903932014671, -54.719891230092394, -53.491244842556135, -52.28290371224164, -51.09467152774303, -49.92635211327641, -48.77774943033919, -47.64866757933546, -46.53891080113186, -45.44828347855883, -44.37659013786237, -43.323635450089135, -42.289224232420395, -41.27316144944434, -40.275252214370525, -39.29530179018471, -38.33311559074165, -37.38849918180268, -36.461258282008444, -35.55119876378822, -34.65812665421592, -33.781848135795805, -32.922169547190954, -32.07889738388673, -31.251838298792627, -30.440799102783494, -29.64558676517128, -28.86600841412059, -28.10187133699535, -27.352982980644722, -26.619150951624857, -25.90018301635444, -25.19588710121068, -24.506071292556243, -23.83054383670682, -23.169113139830944, -22.52158776778861, -21.887776445904343, -21.267488058677646, -20.660531649428364, -20.06671641988012, -19.485851729679897, -18.917747095852526, -18.362212192196186, -17.81905684861121, -17.288091050368934, -16.769124937317176, -16.261968803024757, -15.766433093863993, -15.282328408031795, -14.809465494510864, -14.347655251970025, -13.896708727604633, -13.456437115918161, -13.0266517574435 ...
